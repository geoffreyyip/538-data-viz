# %% [markdown]
# Here we read data from the movies.csv provided by FiveThirtyEight's GitHub portfolio.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# movies.csv taken from FiveThirtyEight's GitHub
movies_df = pd.read_csv('movies.csv')

# %%
# need to convert clean_test values to something usable. 
def convert(x):
    if x == 'nowomen':
        return 0
    if x == 'notalk':
        return 1
    if x == 'men':
        return 2
    if x == 'dubious' or 'men':
        return 3

movies_df['clean_test'] = movies_df['clean_test'].apply(convert)

movies_df.head()
# Out:
#    year       imdb             title             test  clean_test binary  \
# 0  2013  tt1711425     21 &amp; Over           notalk           1   FAIL
# 1  2012  tt1343727          Dredd 3D      ok-disagree           3   PASS
# 2  2013  tt2024544  12 Years a Slave  notalk-disagree           1   FAIL
# 3  2013  tt1272878            2 Guns           notalk           1   FAIL
# 4  2013  tt0453562                42              men           2   FAIL
#
#      budget  domgross   intgross      code  budget_2013$  domgross_2013$  \
# 0  13000000  25682380   42195766  2013FAIL      13000000        25682380
# 1  45000000  13414714   40868994  2012PASS      45658735        13611086
# 2  20000000  53107035  158607035  2013FAIL      20000000        53107035
# 3  61000000  75612460  132493015  2013FAIL      61000000        75612460
# 4  40000000  95020213   95020213  2013FAIL      40000000        95020213
#
#    intgross_2013$  period code  decade code     x_ROI
# 0        42195766            1            1  3.245828
# 1        41467257            1            1  0.908200
# 2       158607035            1            1  7.930352
# 3       132493015            1            1  2.172017
# 4        95020213            1            1  2.375505

# %%
# Next we need 9 buckets of dates. 
# NOTE TO SELF: THERE'S GOTTA BE A BETTER WAY OF WRITING THIS.
def group(x):
    if x in range(1970, 1975):
        return 1
    elif x in range(1975, 1980):
        return 2
    elif x in range(1980, 1985):
        return 3
    elif x in range(1985, 1990):
        return 4
    elif x in range(1990, 1995):
        return 5
    elif x in range(1995, 2000):
        return 6
    elif x in range(2000, 2005):
        return 7
    elif x in range(2005, 2010):
        return 8
    elif x in range(2010, 2015):
        return 9

movies_df['bucket'] = movies_df['year'].apply(group)
movies_df[['year', 'bucket']]
# Out:
#       year  bucket
# 0     2013       9
# 1     2012       9
# 2     2013       9
# 3     2013       9
# 4     2013       9
# 5     2013       9
# 6     2013       9
# 7     2013       9
# 8     2013       9
# 9     2013       9
# 10    2013       9
# 11    2013       9
# 12    2013       9
# 13    2013       9
# 14    2013       9
# 15    2013       9
# 16    2013       9
# 17    2013       9
# 18    2013       9
# 19    2013       9
# 20    2013       9
# 21    2013       9
# 22    2013       9
# 23    2013       9
# 24    2013       9
# 25    2013       9
# 26    2013       9
# 27    2013       9
# 28    2013       9
# 29    2013       9
# ...    ...     ...
# 1764  1976       2
# 1765  1976       2
# 1766  1976       2
# 1767  1976       2
# 1768  1975       2
# 1769  1975       2
# 1770  1975       2
# 1771  1975       2
# 1772  1975       2
# 1773  1974       1
# 1774  1974       1
# 1775  1974       1
# 1776  1974       1
# 1777  1974       1
# 1778  1974       1
# 1779  1974       1
# 1780  1973       1
# 1781  1973       1
# 1782  1973       1
# 1783  1973       1
# 1784  1973       1
# 1785  1972       1
# 1786  1972       1
# 1787  1972       1
# 1788  1971       1
# 1789  1971       1
# 1790  1971       1
# 1791  1971       1
# 1792  1971       1
# 1793  1970       1
#
# [1794 rows x 2 columns]

# %%
def x_group(x):
    for i in range(0, (2015-1970)//5):
        if x in range(1970 + 5*i, 1975 + 5*i):
            return i

movies_df['x_bucket'] = movies_df['year'].apply(x_group)
movies_df[['year', 'bucket', 'x_bucket']]
# Out:
#       year  bucket  x_bucket
# 0     2013       9         8
# 1     2012       9         8
# 2     2013       9         8
# 3     2013       9         8
# 4     2013       9         8
# 5     2013       9         8
# 6     2013       9         8
# 7     2013       9         8
# 8     2013       9         8
# 9     2013       9         8
# 10    2013       9         8
# 11    2013       9         8
# 12    2013       9         8
# 13    2013       9         8
# 14    2013       9         8
# 15    2013       9         8
# 16    2013       9         8
# 17    2013       9         8
# 18    2013       9         8
# 19    2013       9         8
# 20    2013       9         8
# 21    2013       9         8
# 22    2013       9         8
# 23    2013       9         8
# 24    2013       9         8
# 25    2013       9         8
# 26    2013       9         8
# 27    2013       9         8
# 28    2013       9         8
# 29    2013       9         8
# ...    ...     ...       ...
# 1764  1976       2         1
# 1765  1976       2         1
# 1766  1976       2         1
# 1767  1976       2         1
# 1768  1975       2         1
# 1769  1975       2         1
# 1770  1975       2         1
# 1771  1975       2         1
# 1772  1975       2         1
# 1773  1974       1         0
# 1774  1974       1         0
# 1775  1974       1         0
# 1776  1974       1         0
# 1777  1974       1         0
# 1778  1974       1         0
# 1779  1974       1         0
# 1780  1973       1         0
# 1781  1973       1         0
# 1782  1973       1         0
# 1783  1973       1         0
# 1784  1973       1         0
# 1785  1972       1         0
# 1786  1972       1         0
# 1787  1972       1         0
# 1788  1971       1         0
# 1789  1971       1         0
# 1790  1971       1         0
# 1791  1971       1         0
# 1792  1971       1         0
# 1793  1970       1         0
#
# [1794 rows x 3 columns]

# %%
# Note, crosstab is not an attribute. It is a function. It must be called.
movies_xt = pd.crosstab(movies_df['x_bucket'], movies_df['clean_test'])
movies_xt
# Out:
# clean_test   0    1   2    3
# x_bucket
# 0            0   13   3    5
# 1            4   14   4   11
# 2           10   16  10   22
# 3            7   21   9   30
# 4           13   26  13   38
# 5           11   79  24  133
# 6           29   90  36  197
# 7           35  134  50  269
# 8           32  121  45  240

# %%
movies_xt_pct = movies_xt.div(movies_xt.sum(axis=1), axis=0)
movies_xt_pct
# Out:
# clean_test         0         1         2         3
# x_bucket
# 0           0.000000  0.619048  0.142857  0.238095
# 1           0.121212  0.424242  0.121212  0.333333
# 2           0.172414  0.275862  0.172414  0.379310
# 3           0.104478  0.313433  0.134328  0.447761
# 4           0.144444  0.288889  0.144444  0.422222
# 5           0.044534  0.319838  0.097166  0.538462
# 6           0.082386  0.255682  0.102273  0.559659
# 7           0.071721  0.274590  0.102459  0.551230
# 8           0.073059  0.276256  0.102740  0.547945

# %%
# NOTE TO SELF: NEED TO INVERT THE STACK ORDER
# GOOD SCORES SHOULD BE ON THE BOTTOM
movies_xt_pct.plot(kind='bar', stacked=True)

# %%
import matplotlib.image as mpimg

img = mpimg.imread('beta.png')
img
# Out:
# array([[[ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         ...,
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647]],
#
#        [[ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         ...,
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647]],
#
#        [[ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         ...,
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647],
#         [ 0.94117647,  0.94117647,  0.94117647]],
#
#        ...,
#        [[ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         ...,
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903]],
#
#        [[ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         ...,
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903]],
#
#        [[ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         ...,
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903],
#         [ 0.35686275,  0.36862746,  0.37254903]]], dtype=float32)

# %%
imgplot = plt.imshow(img)
imgplot

# %%
# TODO: Calculate average gross budget for each rating
# TODO: Create a sideways histogram. Or bar chart.
# TODO: No y-axis, just the titles of each rating to the right side of each bar

# Data needed: 'budget_2013$', 'clean_test'
# Filters need: films since 1990

beta = movies_df[movies_df['year'] >= 1990]
beta = beta.groupby('test').median()
beta_plot = beta['budget_2013$']
beta_plot
# Out:
# test
# dubious             31617675.5
# dubious-disagree    46364637.0
# men                 38160582.5
# men-disagree        45383537.5
# notalk              53102348.0
# notalk-disagree     67412609.0
# nowomen             40311473.0
# nowomen-disagree    54286580.0
# ok                  29703299.0
# ok-disagree         58312784.5
# Name: budget_2013$, dtype: float64

# %%
beta_plot.plot(kind='barh', legend=True)
plt.xlabel('Budget in Millions') # Need to divide by 1,000,000 to do this
plt.title('Median Budget for Films Since 1990', fontsize=18)
# TODO: Remove x-axis and y-axis. Replace with number values at tips of bars
beta_plot
# Out:
# test
# dubious             31617675.5
# dubious-disagree    46364637.0
# men                 38160582.5
# men-disagree        45383537.5
# notalk              53102348.0
# notalk-disagree     67412609.0
# nowomen             40311473.0
# nowomen-disagree    54286580.0
# ok                  29703299.0
# ok-disagree         58312784.5
# Name: budget_2013$, dtype: float64

# %%
img = mpimg.imread('gamma.png')
plt.imshow(img)

# %%
# TODO: Calculate dollar earned per dollar spent.
# TODO: Split by Bechdel score.
# TODO: Make a bar chart for both US/ Canada, and International

# Looks like I'll have to use two subplots
# A Figure title, and then titles for the two subplots
# Beyond that, the graphing is easy.
# Data Needed: 'domgross_2013$', 'intgross_2013$', 'clean_test'

fig = plt.figure()
movies_df['ROI'] = movies_df['domgross']/ movies_df['budget']
gamma1 = movies_df[movies_df['year'] >= 1990].groupby('clean_test').median()
first_graph = gamma1['ROI'].plot(kind='barh')
print(gamma1['ROI'])
# Out:
# clean_test
# 0    0.996369
# 1    1.222995
# 2    1.305368
# 3    1.370452
# Name: ROI, dtype: float64

# %%
movies_df['x_ROI'] = (movies_df['intgross'] - movies_df['domgross'])/ movies_df['budget']
gamma2 = movies_df[movies_df['year'] >= 1990].groupby('clean_test').median()
second_graph = gamma2['x_ROI'].plot(kind='barh', color='y')
gamma2['x_ROI']
# Out:
# clean_test
# 0    1.163738
# 1    1.174574
# 2    1.055220
# 3    1.174410
# Name: x_ROI, dtype: float64

# %%
plt.figure()
first_graph
