# %% [markdown]
# This notebook was prepared by [Geoffrey Yip](www.github.com/geoffreyyip).
# Data Set is taken from [FiveThirtyEight's GitHub](github.com/fivethirtyeight/data/tree/master/bechdel).
# Original graphics from ["The Dollar-and-Cents Case Against Hollywood's Exclusion of Women"](www.fivethirtyeight.com/features/the-dollar-and-cents-case-against-hollywoods-exclusion-of-women/)
#
# # 538-Data-Viz: Recreating FiveThirtyEight's Graphics in Matplotlib + Pandas

# %%
from IPython.display import Image

Image('alpha.png')

# %% [markdown]
# First, let's import our tools. Pandas will be used to manipulate the data. Matplotlib will be used to visualize it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %% [markdown]
# Next we load the data set into a DataFrame. Data Set is taken from [FiveThirtyEight's GitHub](github.com/fivethirtyeight/data/tree/master/bechdel).

# %%
movies_df = pd.read_csv('movies.csv')

movies_df.head()
# Out:
#    year       imdb             title             test clean_test binary  \
# 0  2013  tt1711425     21 &amp; Over           notalk     notalk   FAIL
# 1  2012  tt1343727          Dredd 3D      ok-disagree         ok   PASS
# 2  2013  tt2024544  12 Years a Slave  notalk-disagree     notalk   FAIL
# 3  2013  tt1272878            2 Guns           notalk     notalk   FAIL
# 4  2013  tt0453562                42              men        men   FAIL
#
#      budget  domgross   intgross      code  budget_2013$  domgross_2013$  \
# 0  13000000  25682380   42195766  2013FAIL      13000000        25682380
# 1  45000000  13414714   40868994  2012PASS      45658735        13611086
# 2  20000000  53107035  158607035  2013FAIL      20000000        53107035
# 3  61000000  75612460  132493015  2013FAIL      61000000        75612460
# 4  40000000  95020213   95020213  2013FAIL      40000000        95020213
#
#    intgross_2013$  period code  decade code
# 0        42195766            1            1
# ...

# %% [markdown]
# We got a lot of variables here. However, we will only need two for our first graphic: year, and clean_test. Year is used so we can chart over time. Clean_test is used to show how movies perform on the Bechdel Test.
#
# We can create a crosstab of year and clean_test ratings, and then plot a bar chart.

# %%
alpha_xt = pd.crosstab(movies_df['year'], movies_df['clean_test'])
alpha_xt.head()
# Out:
# clean_test  dubious  men  notalk  nowomen  ok
# year
# 1970              0    0       0        0   1
# 1971              0    1       4        0   0
# 1972              0    0       2        0   1
# 1973              0    1       3        0   1
# 1974              0    1       4        0   2

# %% [markdown]
# Here's part of the crosstab.

# %%
alpha_xt.plot(kind='bar', 
              stacked=True)

# %% [markdown]
# And here's the bar plot.
#
# Needs some work. There's way too many columns. Let's group the years into 5-year periods.

# %%
# in the first loop, i = 0 and the function scans range(1970, 1975)
# in the 2nd loop, i = 1, and the function scans range(1975, 1980)
# and so forth

# it then returns a string of the time period it scanned
# in the first loop, it returns "1970-1974"
# in the 2nd loop, it returns "1975-1979"
# and so forth

def group(x):
    # this determines how many 5-year periods to scan through
    for i in range(0, (2015-1970) // 5): 
        if x in range(1970 + 5*i, 1975 + 5*i):
            return("{}-{}").format(1970 + 5*i, 1974 + 5*i)
            
        
movies_df['phase'] = movies_df['year'].apply(group)

print(movies_df[['year', 'phase']].sample(5))
# Out:
#       year      phase
# 999   2004  2000-2004
# 641   2008  2005-2009
# 1149  2002  2000-2004
# 1174  2001  2000-2004
# 1103  2002  2000-2004

# %% [markdown]
# Looks good. Let's plot the graph again, but using 'phase' instead of 'year'.

# %%
alpha_xt = pd.crosstab(movies_df['phase'], movies_df['clean_test'])
alpha_xt.plot(kind='bar', stacked=True)

# %% [markdown]
# Better, except it's hard to compare time periods. The 2010-2015 period has 438 movies, whereas the 1970-1975 period has only 21. Proportions would be helpful here. Let's normalize the data so that each time period adds up to 100%.

# %%
alpha_xt
# Out:
# clean_test  dubious  men  notalk  nowomen   ok
# phase
# 1970-1974         0    3      13        0    5
# 1975-1979         2    4      14        4    9
# 1980-1984         9   10      16       10   13
# 1985-1989         7    9      21        7   23
# 1990-1994         5   13      26       13   33
# 1995-1999        19   24      79       11  114
# 2000-2004        19   36      90       29  178
# 2005-2009        38   50     134       35  231
# 2010-2014        43   45     121       32  197

# %% [markdown]
# Here's the original crosstab.

# %%
# Express everything as a percentage of total
alpha_xt_pct = alpha_xt.div(alpha_xt.sum(axis=1), axis=0)
alpha_xt_pct
# Out:
# clean_test   dubious       men    notalk   nowomen        ok
# phase
# 1970-1974   0.000000  0.142857  0.619048  0.000000  0.238095
# 1975-1979   0.060606  0.121212  0.424242  0.121212  0.272727
# 1980-1984   0.155172  0.172414  0.275862  0.172414  0.224138
# 1985-1989   0.104478  0.134328  0.313433  0.104478  0.343284
# 1990-1994   0.055556  0.144444  0.288889  0.144444  0.366667
# 1995-1999   0.076923  0.097166  0.319838  0.044534  0.461538
# 2000-2004   0.053977  0.102273  0.255682  0.082386  0.505682
# 2005-2009   0.077869  0.102459  0.274590  0.071721  0.473361
# 2010-2014   0.098174  0.102740  0.276256  0.073059  0.449772

# %% [markdown]
# And here is the normalized crosstab.

# %%
alpha_xt_pct.plot(kind='bar', stacked=True)

# %% [markdown]
# Almost there! We have two more things to do. First we need to reorder the bar stacks. We want the good movies (movies that passed the Bechdel test) on the bottom and the bad movies on the top.
#
# Second, we need to add a clear contrast between the good and the bad movies. Right now, we have five distinct colors. We want varying shades of two colors, say red and blue.
#
# Step 1: Rearrange columns. Step 2: Assign colors.

# %%
alpha_xt_pct.columns
# Out:
# Index(['dubious', 'men', 'notalk', 'nowomen', 'ok'], dtype='object', name='clean_test')

# %%
# here we reassign columns from good to bad
alpha_xt_pct = alpha_xt_pct[['ok', 'dubious', 'men', 'notalk', 'nowomen']]

# here we assign colors
alpha_xt_pct.plot(kind='bar', 
                  stacked=True, 
                  color= ('darkblue', 'blue','pink', 'red', 'maroon'))

# %% [markdown]
# Cool! Let's get that pesky legend out of the way, shrink the distance between the bars, and rebrand the y-axis values as percentages.

# %%
alpha_xt_pct = alpha_xt_pct[['ok', 'dubious', 'men', 'notalk', 'nowomen']]

ax = alpha_xt_pct.plot(kind='bar', 
                  stacked=True, 
                  color= ('darkblue', 'blue','pink', 'red', 'maroon'),
                  width=1,  # if bar width is 1, then it leaves no space between bars
                  ylim=[0,1],    # limits y-axis to values between 0 and 100%
                  figsize=(8,6),
                  fontsize=14,
                 )
ax.set_title('Bechdel Test Over Time \nHow women are represented in movies',
             fontsize=20,
             fontweight='bold')


handles, labels = ax.get_legend_handles_labels()
labels = ['Passes Bechdel Test', 
          'Dubious', 
          'Women only talk about men', 
          'Women don\'t talk to each other', 
          'Fewer than two women']

ax.legend(handles[::-1], labels[::-1], # reverses the legend order
          loc='center left', 
          bbox_to_anchor=(1, 0.5),    # moves the legend outside graph
          fontsize=14,)    

vals = ax.get_yticks()
ax.set_yticklabels(['{}%'.format(int(x*100)) for x in vals])    # formats the tick labels with percentages

# Loads the original image for comparison
Image('alpha.png')

# %% [markdown]
# One down! Let's move onto the next two.

# %%
Image('beta.png')

# %% [markdown]
# Let's use a horizontal bar chart for this one. Two variables will be needed for this one: the budget adjusted for 2013 dollars, and the Bechdel test ratings. We will also need to filter for movies released in 1990 or later as the original 538 article did.

# %%
# Filters movies to those released in 1990 or later
movies_df_X = movies_df[movies_df['year'] >= 1990]
# Returns median of each rating
movies_df_X = movies_df_X.groupby('clean_test').median()

movies_df_X
# Out:
#             year    budget    domgross     intgross  budget_2013$  \
# clean_test
# dubious     2007  30000000  41263140.0   79114085.0      35790994
# men         2006  30000000  46923917.5   86819516.5      39737689
# notalk      2006  45500000  54333290.0  100853753.0      56570083
# nowomen     2006  39500000  39687694.0   81150788.0      43373066
# ok          2005  25000000  37744889.0   66298908.0      31070724
#
#             domgross_2013$  intgross_2013$  period code  decade code
# clean_test
# dubious         49173429.0      89883201.0            2            2
# men             56392786.0      99578022.5            2            2
# notalk          63890455.0     123102194.0            2            2
# nowomen         44891296.5      89509349.0            2            2
# ok              45330446.5      80124349.0            2            2

# %% [markdown]
# We have 5 categories here. We want to reduce down to 4. 'dubious' ratings still count as passing the Bechdel test. Therefore we want to list 'dubious' values as 'ok' values.  Let's define a new column.

# %%
def transform_clean_test(x):
    if x == 'dubious':
        return 'ok'
    else:
        return x
    
movies_df['clean_test_X'] = movies_df['clean_test'].apply(transform_clean_test)

movies_df['clean_test_X'].unique() # checks to make sure we have only 4 unique values left
# Out:
# array(['notalk', 'ok', 'men', 'nowomen'], dtype=object)

# %% [markdown]
# Alright, now we can plot it.

# %%
# performs the same procedure as before, except using clean_test_X instead of clean_test
movies_df_X = movies_df[movies_df['year'] >= 1990]
movies_df_X = movies_df_X.groupby('clean_test_X').median()

ax = movies_df_X['budget_2013$'].plot(kind='barh')

# %% [markdown]
# Simple. But the bars are in the wrong order. And the y-labels need to be more descriptive. And we need value labels on the bars.

# %%
movies_df_X
# Out:
#               year    budget    domgross     intgross  budget_2013$  \
# clean_test_X
# men           2006  30000000  46923917.5   86819516.5      39737689
# notalk        2006  45500000  54333290.0  100853753.0      56570083
# nowomen       2006  39500000  39687694.0   81150788.0      43373066
# ok            2006  25500000  37771017.0   68336997.0      31652174
#
#               domgross_2013$  intgross_2013$  period code  decade code
# clean_test_X
# men               56392786.0      99578022.5            2            2
# notalk            63890455.0     123102194.0            2            2
# nowomen           44891296.5      89509349.0            2            2
# ok                45709979.0      81832836.0            2            2

# %% [markdown]
# Let's rename the index.

# %%
# rename method takes a dictionary object
movies_df_X.rename(index={'men':'Women only talk about men', 
                          'notalk':'Women don\'t talk to each other', 
                          'nowomen':'Fewer than two women', 
                          'ok':'Passes Bechdel Test'},
                   inplace=True)
movies_df_X['budget_2013$']
# Out:
# clean_test_X
# Women only talk about men         39737689
# Women don't talk to each other    56570083
# Fewer than two women              43373066
# Passes Bechdel Test               31652174
# Name: budget_2013$, dtype: int64

# %%
# Defines a figure size of 7 by 2 inches.
plt.figure(figsize=(7,2))

# foobar is a rearranged DataFrame. It is arrange in the order of the columns listed
foobar = movies_df_X['budget_2013$'].ix[['Fewer than two women',
                                         'Women don\'t talk to each other',
                                         'Women only talk about men',
                                         'Passes Bechdel Test']]

# now we plot the DataFrame. 
ax = foobar.plot(kind='barh', 
                 xlim=[0, 65 * 10**6],   # This is saying from 0 to 6.5 million
                 fontsize=14,
                 color='lightblue',
                 grid=False,
                 width=0.60)

# removes all the borders for a cleaner look; removes the x-axis as well
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().set_visible(False)

# face color is background color
# we set the face color for both the figure and the axes to be light grey.
plt.gcf().patch.set_facecolor('lightgrey')
ax.patch.set_facecolor('lightgrey')

ax.set_title('Median Budget for Films Since 1990\n 2013 dollars',
             fontsize = 24, 
             fontweight='bold')

# Here we use the bar rectangles to determine appropriate labels.
rects = ax.patches

for i in range(0, len(rects)):
    rect = rects[i]
    height = rect.get_y() + 0.2
    width = rect.get_width() + 10**6
    value = "${}m".format(width//10**6)
    ax.text(width, height, value, fontsize=14)

# here we print the original image for comparison
Image('beta.png')

# %% [markdown]
# Two down! One to go.
#
# And this is a tedious one.

# %%
Image('gamma.png')

# %% [markdown]
# Let's start by plotting the left graph.

# %%
# Before we get the median of each clean_test result, we must calculate "Dollars Earned for Every Dollar Spent"
# So first, let's add a "ROI" (Return on Investment) column to the DataFrame
movies_df['ROI'] = movies_df['domgross_2013$'] / movies_df['budget_2013$']

# Then, we can filter by movies released in 1990 or later.
movies_df_Y = movies_df[movies_df['year'] >= 1990]

# Remeber we have to filter by clean_test_X, because we want the 'dubious' result to be merged into the 'ok' result.
movies_df_Y = movies_df_Y.groupby('clean_test_X').median()

movies_df_Y['ROI']
# Out:
# clean_test_X
# men        1.305368
# notalk     1.222995
# nowomen    0.997523
# ok         1.370452
# Name: ROI, dtype: float64

# %%
# renames the labels
movies_df_Y.rename(index={'men':'Women only talk about men', 
                          'notalk':'Women don\'t talk to each other', 
                          'nowomen':'Fewer than two women', 
                          'ok':'Passes Bechdel Test'},
                   inplace=True)

movies_df_Y['ROI']
# Out:
# clean_test_X
# Women only talk about men         1.305368
# Women don't talk to each other    1.222995
# Fewer than two women              0.997523
# Passes Bechdel Test               1.370452
# Name: ROI, dtype: float64

# %%
# Similiar code to before.
foobar = movies_df_Y['ROI'].ix[['Fewer than two women',
                                'Women don\'t talk to each other',
                                'Women only talk about men',
                                'Passes Bechdel Test']]

ax = foobar.plot(kind='barh', 
                 xlim=[0, 1.5],
                 fontsize=14,
                 color='lightblue',
                 grid=False,
                 width=0.60)

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().set_visible(False)


plt.gcf().patch.set_facecolor('lightgrey')
ax.patch.set_facecolor('lightgrey')

ax.set_title('U.S. and Canada',
             fontsize = 24, fontweight='bold')

rects = ax.patches

for i in range(0, len(rects)):
    rect = rects[i]
    height = rect.get_y() 
    width = rect.get_width() 
    value = "${:.2f}".format(width)    # ':.2f' means to use only two decimal places
    ax.text(width, height, value, fontsize=14)

# %% [markdown]
# That's the left side. Now let's get the right side.

# %%
# We need international ROI. 
# 538 calculated this subtracting Domestic Gross from International Gross
# In order words, "International Dollars Earned Per Dollar Spent" in the graphic...
# ...includes every country in the world except U.S. and Canada.

# International ROI will need to account for this.
movies_df['ROI_X'] = (movies_df['intgross_2013$'] - movies_df['domgross_2013$']) / movies_df['budget_2013$']
movies_df_Z = movies_df[movies_df['year'] >= 1990].groupby('clean_test_X').median()
movies_df_Z['ROI_X']
# Out:
# clean_test_X
# men        1.055220
# notalk     1.174574
# nowomen    1.169856
# ok         1.174410
# Name: ROI_X, dtype: float64

# %%
# Same renaming process
movies_df_Z.rename(index={'men':'Women only talk about men', 
                          'notalk':'Women don\'t talk to each other', 
                          'nowomen':'Fewer than two women', 
                          'ok':'Passes Bechdel Test'},
                   inplace=True)

movies_df_Z['ROI_X']
# Out:
# clean_test_X
# Women only talk about men         1.055220
# Women don't talk to each other    1.174574
# Fewer than two women              1.169856
# Passes Bechdel Test               1.174410
# Name: ROI_X, dtype: float64

# %% [markdown]
# Slightly modified code for graphing.

# %%
# different dataframe, different column
# ROI_X replaces ROI, movies_df_Z replaces movies_df
foobar = movies_df_Z['ROI_X'].ix[['Fewer than two women',    
                                  'Women don\'t talk to each other',
                                  'Women only talk about men',
                                  'Passes Bechdel Test']]


ax = foobar.plot(kind='barh', 
                 xlim=[0, 1.5],    # xlim is now set from 0 to 1.5
                 fontsize=14,
                 color='yellow',
                 grid=False,
                 width=0.60)    

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().set_visible(False)


plt.gcf().patch.set_facecolor('lightgrey')
ax.patch.set_facecolor('lightgrey')

ax.set_title('International',    # different title
             fontsize = 24, 
             fontweight='bold')

rects = ax.patches

for i in range(0, len(rects)):
    rect =rects[i]
    height = rect.get_y() 
    width = rect.get_width() 
    value = "${:.2f}".format(width)    # ':.2f' means to use only two decimal places
    ax.text(width, height, value, fontsize=14)

# %% [markdown]
# And now for the long one. We need to combine the two subplots into one large figure. We'll be reusing a lot of code here.

# %%
# First, we need to specify the figure size. 
# This must be done before plotting the subplots.
plt.figure(figsize=(7,4)) 

# Next, we want to specify the dimensions of the Figure 
# This figure will be 1 by 2, or 1 subplot tall, and 2 subplots wide.
# We want the U.S. and Canada graph to be the first one, or the one on the left.
plt.subplot(1, 2, 1)

# Next, all the code from the left graph.
foobar = movies_df_Y['ROI'].ix[['Fewer than two women',
                                'Women don\'t talk to each other',
                                'Women only talk about men',
                                'Passes Bechdel Test']]

ax = foobar.plot(kind='barh', 
                 xlim=[0, 1.5],
                 fontsize=14,
                 color='lightblue',
                 grid=False,
                 width=0.60)

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().set_visible(False)


plt.gcf().patch.set_facecolor('lightgrey')
ax.patch.set_facecolor('lightgrey')
ax.set_title('U.S. and Canada',
             fontsize = 14, fontweight='bold')


rects = ax.patches

for i in range(0, len(rects)):
    rect =rects[i]
    height = rect.get_y() + 0.2    # added a little to center the label
    width = rect.get_width()
    value = "${:.2f}".format(width)    
    ax.text(width, height, value, fontsize=14)

################################################################################    
# Next, we specify the second subplot in that same 1x2 grid.
plt.subplot(1, 2, 2)

# Same code, except we remove the y-axis
foobar = movies_df_Z['ROI_X'].ix[['Fewer than two women',    
                                  'Women don\'t talk to each other',
                                  'Women only talk about men',
                                  'Passes Bechdel Test']]

ax = foobar.plot(kind='barh', 
                 xlim=[0, 1.5],
                 fontsize=14,
                 color='yellow',
                 grid=False,
                 width=0.60)

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)    # Here, we remove the y_axis

plt.gcf().patch.set_facecolor('lightgrey')
ax.patch.set_facecolor('lightgrey')
ax.set_title('International',    
             fontsize = 14, 
             fontweight='bold')


rects = ax.patches

for i in range(0, len(rects)):
    rect =rects[i]
    height = rect.get_y() + 0.2    # added a little to center the label
    width = rect.get_width() 
    value = "${:.2f}".format(width)    
    ax.text(width, height, value, fontsize=14)    
    
    
# Finally we add a title.     
plt.suptitle('Dollars Earned Per Dollar Spent: 2013 Dollars',
             fontsize=24,
             fontweight='bold',
             y=1.04)

Image('gamma.png')

# %% [markdown]
# And that's that! Matplotlib isn't quite as good as d3.js (what 538 uses for its visualizations) but it's a lot more flexible than expected.
